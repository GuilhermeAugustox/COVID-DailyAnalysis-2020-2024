# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#df = pd.read_csv("WHO-COVID-19-global-data.csv", sep=";")
#df
# Out:
#       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        05/01/2020           AF  Afghanistan       EMRO        NaN
# 1        12/01/2020           AF  Afghanistan       EMRO        NaN
# 2        19/01/2020           AF  Afghanistan       EMRO        NaN
# 3        26/01/2020           AF  Afghanistan       EMRO        NaN
# 4        02/02/2020           AF  Afghanistan       EMRO        NaN
# ...             ...          ...          ...        ...        ...
# 57835    14/07/2024           ZW     Zimbabwe       AFRO        NaN
# 57836    21/07/2024           ZW     Zimbabwe       AFRO        1.0
# 57837    28/07/2024           ZW     Zimbabwe       AFRO        NaN
# 57838    04/08/2024           ZW     Zimbabwe       AFRO        NaN
# 57839    11/08/2024           ZW     Zimbabwe       AFRO        NaN
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     0         NaN                  0
# ...

# %% [markdown]
# Legenda
# AFRO -

# %%
df = pd.read_csv('WHO-COVID-19-global-table-data.csv', sep=',')
df
# Out:
#                                       Name       WHO Region  \
# 0                                  Belarus           Europe
# 1                                    China  Western Pacific
# 2                            French Guiana              NaN
# 3                                   Latvia           Europe
# 4         Saint Vincent and the Grenadines         Americas
# ..                                     ...              ...
# 236                              Argentina         Americas
# 237       Democratic Republic of the Congo           Africa
# 238                                  Nepal  South-East Asia
# 239  Democratic People's Republic of Korea  South-East Asia
# 240                           Turkmenistan           Europe
#
#      Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0                    994037.0                                         10520.0
# 1                  99375079.0                                          6754.0
# ...

# %%
df.head()
# Out:
#                                Name       WHO Region  \
# 0                           Belarus           Europe
# 1                             China  Western Pacific
# 2                     French Guiana              NaN
# 3                            Latvia           Europe
# 4  Saint Vincent and the Grenadines         Americas
#
#    Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0                  994037.0                                         10520.0
# 1                99375079.0                                          6754.0
# 2                   98041.0                                         32825.0
# 3                  977765.0                                         51254.0
# 4                    9674.0                                          8720.0
#
#    Cases - newly reported in last 7 days  \
# 0                                    NaN
# 1                                 1860.0
# 2                                    NaN
# ...

# %% [markdown]
# Levantamentos Estatísticos

# %% [markdown]
# Geral

# %%
estatisticas_gerais = df.describe()
estatisticas_gerais

# %% [markdown]
# Estatística de Coluna "Total de Casos Acumulados"

# %%
media_casos = df['Cases - cumulative total'].mean()
print(f'Média de casos acumulados: {media_casos}')
# Out:
# Média de casos acumulados: 6439146.082987552

# %%
mediana_casos = df['Cases - cumulative total'].median()
print(f'Mediana de casos acumulados: {mediana_casos}')
# Out:
# Mediana de casos acumulados: 172533.0

# %%
desvio_padrao_casos = df['Cases - cumulative total'].std()
print(f'Desvio padrão: {desvio_padrao_casos}')
# Out:
# Desvio padrão: 51032152.55032862

# %%
casos_min = df['Cases - cumulative total'].min()
casos_max = df['Cases - cumulative total'].max()

print(f'Casos Acumulados Mínimo: {casos_min}')
print(f'Casos Acumulados Máximo: {casos_max}')
# Out:
# Casos Acumulados Mínimo: 0.0
# Casos Acumulados Máximo: 775917104.0

# %% [markdown]
# Estatística de Coluna "Total de Mortes Acumuladas"

# %%
mortes_media = df['Deaths - cumulative total'].mean()
print(f'Média de mortes acumuladas: {mortes_media}')
# Out:
# Média de mortes acumuladas: 58575.775933609955

# %%
mortes_mediana = df['Deaths - cumulative total'].median()
print(f'Mediana de mortes acumuladas: {mortes_mediana}')
# Out:
# Mediana de mortes acumuladas: 1468.0

# %%
mortes_desvio_padrao = df['Cases - cumulative total'].std()
print(f'Desvio padrão: {mortes_desvio_padrao}')
# Out:
# Desvio padrão: 51032152.55032862

# %%
mortes_min = df['Deaths - cumulative total'].min()
mortes_max = df['Deaths - cumulative total'].max()

print(f'Mortes Acumuladas Mínimo: {mortes_min}')
print(f'Mortes Acumuladas Máximo: {mortes_max}')
# Out:
# Mortes Acumuladas Mínimo: 0.0
# Mortes Acumuladas Máximo: 7058381.0

# %% [markdown]
# Estatísticas da Coluna Categórica

# %%
#Contagem de países por cada região
contagem_paises_por_regioes = df['WHO Region'].value_counts()
contagem_paises_por_regioes
# Out:
# WHO Region
# Europe                   55
# Americas                 47
# Africa                   47
# Western Pacific          34
# Eastern Mediterranean    22
# South-East Asia          11
# Other                     6
# Name: count, dtype: int64

# %%
#Contagem de quantidade de regiões
num_regioes = df['WHO Region'].nunique()
num_regioes
# Out:
# 7

# %% [markdown]
# Estatística das Colunas com Valores Faltantes

# %%
valores_nulos = df.isnull().sum()
valores_nulos
# Out:
# Name                                                              0
# WHO Region                                                       19
# Cases - cumulative total                                          0
# Cases - cumulative total per 100000 population                    9
# Cases - newly reported in last 7 days                           187
# Cases - newly reported in last 7 days per 100000 population     203
# Cases - newly reported in last 24 hours                         187
# Deaths - cumulative total                                         0
# Deaths - cumulative total per 100000 population                  16
# Deaths - newly reported in last 7 days                          217
# Deaths - newly reported in last 7 days per 100000 population    239
# Deaths - newly reported in last 24 hours                        217
# dtype: int64

# %% [markdown]
# Estatísticas por Regiões

# %%
estatisticas_regioes = df.groupby('WHO Region')['Cases - cumulative total'].describe()
estatisticas_regioes
# Out:
#                        count          mean           std      min        25%  \
# WHO Region
# Africa                  47.0  1.924214e+05  5.903739e+05   6771.0   20481.00
# Americas                47.0  4.100800e+06  1.588146e+07   1403.0   19276.50
# Eastern Mediterranean   22.0  1.064450e+06  1.598713e+06  11945.0  276272.75
# Europe                  55.0  5.082529e+06  9.033038e+06      0.0  372411.50
# Other                    6.0  1.273333e+02  2.865977e+02      2.0       4.25
# South-East Asia         11.0  5.574055e+06  1.327710e+07      0.0  124695.50
# Western Pacific         34.0  6.133917e+06  1.848213e+07     80.0    9274.00
#
#                              50%         75%          max
# WHO Region
# Africa                   63872.0   172108.00    4072765.0
# Americas                108642.0  1162904.50  103436829.0
# Eastern Mediterranean   681952.0  1218268.25    7627863.0
# Europe                 1499712.0  4857715.50   38997490.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
paises = df['Name'].unique()
paises
# Out:
# array(['Belarus', 'China', 'French Guiana', 'Latvia',
#        'Saint Vincent and the Grenadines', 'Guinea-Bissau', 'Niger',
#        'Comoros', 'Antigua and Barbuda', 'Senegal', 'Malawi',
#        'Kyrgyzstan', "C�te d'Ivoire", 'Netherlands (Kingdom of the)',
#        'Saudi Arabia', 'American Samoa', 'Azerbaijan', 'Suriname',
#        'New Caledonia', 'Tokelau', 'Sierra Leone', 'French Polynesia',
#        'Liberia', 'Chad', 'Iran (Islamic Republic of)', 'Mexico',
#        'British Virgin Islands', 'Eswatini', 'Guyana', 'Paraguay',
#        'Cook Islands', 'Belize',
#        'International conveyance (Diamond Princess)',
#        'occupied Palestinian territory, including east Jerusalem',
#        'Global', 'Bahrain', 'Cyprus', 'Fiji', 'Madagascar', 'Indonesia',
#        'Turks and Caicos Islands', 'Sao Tome and Principe', 'Sri Lanka',
#        'Poland', 'Kuwait', 'Jersey', 'Dominican Republic',
#        'Saint Kitts and Nevis', 'Cabo Verde', 'Myanmar', 'Sudan',
# ...

# %%
#ultimo_regis = df.groupby('Country').last().reset_index()
#ultimo_regis
# Out:
#                                                Country Date_reported  \
# 0                                          Afghanistan    11/08/2024
# 1                                              Albania    11/08/2024
# 2                                              Algeria    11/08/2024
# 3                                       American Samoa    11/08/2024
# 4                                              Andorra    11/08/2024
# ..                                                 ...           ...
# 235                                  Wallis and Futuna    11/08/2024
# 236                                              Yemen    11/08/2024
# 237                                             Zambia    11/08/2024
# 238                                           Zimbabwe    11/08/2024
# 239  occupied Palestinian territory, including east...    11/08/2024
#
#     Country_code WHO_region  New_cases  Cumulative_cases  New_deaths  \
# ...

# %%
#df1 = ultimo_regis
#f1
# Out:
#                                                Country Date_reported  \
# 0                                          Afghanistan    11/08/2024
# 1                                              Albania    11/08/2024
# 2                                              Algeria    11/08/2024
# 3                                       American Samoa    11/08/2024
# 4                                              Andorra    11/08/2024
# ..                                                 ...           ...
# 235                                  Wallis and Futuna    11/08/2024
# 236                                              Yemen    11/08/2024
# 237                                             Zambia    11/08/2024
# 238                                           Zimbabwe    11/08/2024
# 239  occupied Palestinian territory, including east...    11/08/2024
#
#     Country_code WHO_region  New_cases  Cumulative_cases  New_deaths  \
# ...

# %%
df.head()
# Out:
#                                Name       WHO Region  \
# 0                           Belarus           Europe
# 1                             China  Western Pacific
# 2                     French Guiana              NaN
# 3                            Latvia           Europe
# 4  Saint Vincent and the Grenadines         Americas
#
#    Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0                  994037.0                                         10520.0
# 1                99375079.0                                          6754.0
# 2                   98041.0                                         32825.0
# 3                  977765.0                                         51254.0
# 4                    9674.0                                          8720.0
#
#    Cases - newly reported in last 7 days  \
# 0                                    NaN
# 1                                 1860.0
# 2                                    NaN
# ...

# %%
por_regiao = df['WHO Region'].value_counts()
por_regiao
# Out:
# WHO Region
# Europe                   55
# Americas                 47
# Africa                   47
# Western Pacific          34
# Eastern Mediterranean    22
# South-East Asia          11
# Other                     6
# Name: count, dtype: int64

# %%
por_regiao.plot(kind='bar')

plt.title('Quantidade de países por região')
plt.xlabel('Regiões')
plt.ylabel('Quantidades de países')

plt.show()

# %%
df.head()

# %% [markdown]
# Separação das colunas à serem utilizadas

# %%
df_total = df.drop(columns=['Cases - cumulative total per 100000 population', 'Cases - newly reported in last 7 days', 'Cases - newly reported in last 7 days per 100000 population', 'Cases - newly reported in last 24 hours', 'Deaths - cumulative total per 100000 population', 'Deaths - newly reported in last 7 days', 'Deaths - newly reported in last 7 days per 100000 population', 'Deaths - newly reported in last 24 hours'])

df_total
# Out:
#                                       Name       WHO Region  \
# 0                                  Belarus           Europe
# 1                                    China  Western Pacific
# 2                            French Guiana              NaN
# 3                                   Latvia           Europe
# 4         Saint Vincent and the Grenadines         Americas
# ..                                     ...              ...
# 236                              Argentina         Americas
# 237       Democratic Republic of the Congo           Africa
# 238                                  Nepal  South-East Asia
# 239  Democratic People's Republic of Korea  South-East Asia
# 240                           Turkmenistan           Europe
#
#      Cases - cumulative total  Deaths - cumulative total
# 0                    994037.0                     7118.0
# 1                  99375079.0                   122309.0
# 2                     98041.0                      413.0
# ...

# %%
total_casos_regiao = df_total.groupby('WHO Region')['Cases - cumulative total'].sum()
total_casos_regiao
# Out:
# WHO Region
# Africa                     9043807.0
# Americas                 192737577.0
# Eastern Mediterranean     23417911.0
# Europe                   279539109.0
# Other                          764.0
# South-East Asia           61314608.0
# Western Pacific          208553177.0
# Name: Cases - cumulative total, dtype: float64

# %%
total_casos_regiao_sorted = total_casos_regiao.sort_values(ascending=False)
total_casos_regiao_sorted.plot(kind='bar')

plt.title('Total de Casos por Região')
plt.xlabel('Regiões')
plt.ylabel('Total de Casos')

plt.show()

# %%
total_mortes_regiao = df_total.groupby('WHO Region')['Deaths - cumulative total'].sum()
total_mortes_regiao
# Out:
# WHO Region
# Africa                    174418.0
# Americas                 3023792.0
# Eastern Mediterranean     351975.0
# Europe                   2273741.0
# Other                         13.0
# South-East Asia           808810.0
# Western Pacific           421359.0
# Name: Deaths - cumulative total, dtype: float64

# %%
total_mortes_regiao_sorted = total_mortes_regiao.sort_values(ascending=False)
total_mortes_regiao_sorted.plot(kind='bar')

plt.title('Total de Mortes por Região')
plt.xlabel('Regiões')
plt.ylabel('Total de Casos')

plt.show()
